# %%
# Import Dependencies
import pandas as pd
import csv
import os
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect
from flask import Flask, jsonify
import json
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Table, Column, Integer, String, Date, Float

# %%
# Create a path fro all the CSVs
Amzn = 'AMZN.csv'
Appl = 'AAPL.csv'
Fb = 'FB.csv'
Goog = 'GOOG.csv'
Msft = 'MSFT.csv'
Nflx = 'NFLX.csv'

# %%
# Create Dataframes with the paths
Amazon = pd.read_csv(Amzn)
Apple = pd.read_csv(Appl)
Facebook = pd.read_csv(Fb)
Google = pd.read_csv(Goog)
Microsoft = pd.read_csv(Msft)
Netflix = pd.read_csv(Nflx)

# %%
# Review what the dataframe looks like
Amazon.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2018-01-02  1172.000000  1190.000000  1170.510010  1189.010010
# 1  2018-01-03  1188.300049  1205.489990  1188.300049  1204.199951
# 2  2018-01-04  1205.000000  1215.869995  1204.660034  1209.589966
# 3  2018-01-05  1217.510010  1229.140015  1210.000000  1229.140015
# 4  2018-01-08  1236.000000  1253.079956  1232.030029  1246.869995
#
#      Adj Close   Volume
# 0  1189.010010  2694500
# 1  1204.199951  3108800
# 2  1209.589966  3022100
# 3  1229.140015  3544700
# 4  1246.869995  4279500

# %%
 # Create a filtered dataframe from specific columns
amzn_cols = ["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]
amzn_transformed= Amazon[amzn_cols].copy()

# Rename the column headers
amzn_transformed = amzn_transformed.rename(columns={"Adj Close": "Adj_Close"
                                                         })
# This is to drop the Close column as it is not necessary.
del amzn_transformed['Close']

# Adds a column for the tickers
amzn_transformed.insert(6,column="Ticker", value= "AMZN")
amzn_transformed.head()

# Change the datatype of 'Date' to a dateime type
amzn_transformed['Date'] = pd.to_datetime(amzn_transformed['Date'])
amzn_transformed.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Adj_Close           float64
# Volume                int64
# Ticker               object
# dtype: object

# %%
 # Create a filtered dataframe from specific columns
appl_cols = ["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]
appl_transformed= Apple[appl_cols].copy()

# Rename the column headers
appl_transformed = appl_transformed.rename(columns={"Adj Close": "Adj_Close"
                                                         })
# This is to drop the Close column as it is not necessary.
del appl_transformed['Close']

# Adds a column for the tickers
appl_transformed.insert(6,column="Ticker", value= "AAPL")
appl_transformed.head()

# Change the datatype of 'Date' to a dateime type
appl_transformed['Date'] = pd.to_datetime(appl_transformed['Date'])
appl_transformed.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Adj_Close           float64
# Volume                int64
# Ticker               object
# dtype: object

# %%
 # Create a filtered dataframe from specific columns
fb_cols = ["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]
fb_transformed= Facebook[fb_cols].copy()

# Rename the column headers
fb_transformed = fb_transformed.rename(columns={"Adj Close": "Adj_Close"
                                                         })
# This is to drop the Close column as it is not necessary.
del fb_transformed['Close']

# Adds a column for the tickers
fb_transformed.insert(6,column="Ticker", value= "FB")
fb_transformed.head()

# Change the datatype of 'Date' to a dateime type
fb_transformed['Date'] = pd.to_datetime(fb_transformed['Date'])
fb_transformed.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Adj_Close           float64
# Volume                int64
# Ticker               object
# dtype: object

# %%
 # Create a filtered dataframe from specific columns
goog_cols = ["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]
goog_transformed= Google[goog_cols].copy()

# Rename the column headers
goog_transformed = goog_transformed.rename(columns={"Adj Close": "Adj_Close"
                                                         })
# This is to drop the Close column as it is not necessary.
del goog_transformed['Close']

# Adds a column for the tickers
goog_transformed.insert(6,column="Ticker", value= "GOOG")
goog_transformed.head()

# Change the datatype of 'Date' to a dateime type
goog_transformed['Date'] = pd.to_datetime(goog_transformed['Date'])
goog_transformed.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Adj_Close           float64
# Volume                int64
# Ticker               object
# dtype: object

# %%
 # Create a filtered dataframe from specific columns
Msft_cols = ["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]
Msft_transformed= Microsoft[Msft_cols].copy()

# Rename the column headers
Msft_transformed = Msft_transformed.rename(columns={"Adj Close": "Adj_Close"
                                                         })
# This is to drop the Close column as it is not necessary.
del Msft_transformed['Close']

# Adds a column for the tickers
Msft_transformed.insert(6,column="Ticker", value= "MSFT")
Msft_transformed.head()

# Change the datatype of 'Date' to a dateime type
Msft_transformed['Date'] = pd.to_datetime(Msft_transformed['Date'])
Msft_transformed.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Adj_Close           float64
# Volume                int64
# Ticker               object
# dtype: object

# %%
 # Create a filtered dataframe from specific columns
Nflx_cols = ["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]
Nflx_transformed= Netflix[Nflx_cols].copy()

# Rename the column headers
Nflx_transformed = Nflx_transformed.rename(columns={"Adj Close": "Adj_Close"
                                                         })
# This is to drop the Close column as it is not necessary.
del Nflx_transformed['Close']

# Adds a column for the tickers
Nflx_transformed.insert(6,column="Ticker", value= "NFLX")
Nflx_transformed.head()

# Change the datatype of 'Date' to a dateime type
Nflx_transformed['Date'] = pd.to_datetime(Nflx_transformed['Date'])
Nflx_transformed.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Adj_Close           float64
# Volume                int64
# Ticker               object
# dtype: object

# %%
# Appends all the above transformed dataframes into one dataframe
stocks_appended = amzn_transformed.append([Nflx_transformed, Msft_transformed, goog_transformed, fb_transformed, appl_transformed])
stocks_appended
# Out:
#           Date         Open         High          Low    Adj_Close     Volume  \
# 0   2018-01-02  1172.000000  1190.000000  1170.510010  1189.010010    2694500
# 1   2018-01-03  1188.300049  1205.489990  1188.300049  1204.199951    3108800
# 2   2018-01-04  1205.000000  1215.869995  1204.660034  1209.589966    3022100
# 3   2018-01-05  1217.510010  1229.140015  1210.000000  1229.140015    3544700
# 4   2018-01-08  1236.000000  1253.079956  1232.030029  1246.869995    4279500
# ..         ...          ...          ...          ...          ...        ...
# 750 2020-12-23   132.160004   132.429993   130.779999   130.764603   88223700
# 751 2020-12-24   131.320007   133.460007   131.100006   131.773087   54930100
# 752 2020-12-28   133.990005   137.339996   133.509995   136.486053  124486200
# 753 2020-12-29   138.050003   138.789993   134.339996   134.668762  121047300
# 754 2020-12-30   135.580002   135.990005   133.399994   133.520477   96452100
#
#     Ticker
# 0     AMZN
# ...

# %%
# Set the dataframe index to 'Ticker'
stocks_appended.set_index('Ticker')
# Out:
#              Date         Open         High          Low    Adj_Close  \
# Ticker
# AMZN   2018-01-02  1172.000000  1190.000000  1170.510010  1189.010010
# AMZN   2018-01-03  1188.300049  1205.489990  1188.300049  1204.199951
# AMZN   2018-01-04  1205.000000  1215.869995  1204.660034  1209.589966
# AMZN   2018-01-05  1217.510010  1229.140015  1210.000000  1229.140015
# AMZN   2018-01-08  1236.000000  1253.079956  1232.030029  1246.869995
# ...           ...          ...          ...          ...          ...
# AAPL   2020-12-23   132.160004   132.429993   130.779999   130.764603
# AAPL   2020-12-24   131.320007   133.460007   131.100006   131.773087
# AAPL   2020-12-28   133.990005   137.339996   133.509995   136.486053
# AAPL   2020-12-29   138.050003   138.789993   134.339996   134.668762
# AAPL   2020-12-30   135.580002   135.990005   133.399994   133.520477
#
#            Volume
# Ticker
# AMZN      2694500
# AMZN      3108800
# AMZN      3022100
# AMZN      3544700
# ...

# %%
# Create engien that connects to ElephantSQl
engine = create_engine("postgres://qzewnmvp:KLrEMMwqNGoGYgkvTiI5pNANap7CuFbP@ziggy.db.elephantsql.com:5432/qzewnmvp")
Base = automap_base()
Base.prepare(engine, reflect= True)

# %%
# Create a session
session = Session(engine)

# %%
# Append to SQl cloud AWS
.to_sql(name='fang_stocks_2018_2020', con=engine, if_exists='append', index=True)

# %%
# Pull the from the SQl website to verify it is there
stocks_df = pd.read_sql("SELECT * FROM fang_stocks_2018_2020", con=engine)
stocks_df
# Out:
#       index       Date         Open         High          Low    Adj_Close  \
# 0         0 2018-01-02  1172.000000  1190.000000  1170.510010  1189.010010
# 1         1 2018-01-03  1188.300049  1205.489990  1188.300049  1204.199951
# 2         2 2018-01-04  1205.000000  1215.869995  1204.660034  1209.589966
# 3         3 2018-01-05  1217.510010  1229.140015  1210.000000  1229.140015
# 4         4 2018-01-08  1236.000000  1253.079956  1232.030029  1246.869995
# ...     ...        ...          ...          ...          ...          ...
# 4520    750 2020-12-23   132.160004   132.429993   130.779999   130.764603
# 4521    751 2020-12-24   131.320007   133.460007   131.100006   131.773087
# 4522    752 2020-12-28   133.990005   137.339996   133.509995   136.486053
# 4523    753 2020-12-29   138.050003   138.789993   134.339996   134.668762
# 4524    754 2020-12-30   135.580002   135.990005   133.399994   133.520477
#
#          Volume Ticker
# 0       2694500   AMZN
# ...

# %%
# Repeat steps for indvidual stocks
amzn_transformed.to_sql(name='Amazon_stocks', con=engine, if_exists='append', index=True)
appl_transformed.to_sql(name='Apple_stocks', con=engine, if_exists='append', index=True)
fb_transformed.to_sql(name='Facebook_stocks', con=engine, if_exists='append', index=True)

Msft_transformed.to_sql(name='Micrsoft_stocks', con=engine, if_exists='append', index=True)
Nflx_transformed.to_sql(name='Netflix_stocks', con=engine, if_exists='append', index=True)

# %%
amzn_transformed.tail()
# Out:
#           Date         Open         High          Low    Adj_Close   Volume  \
# 750 2020-12-23  3205.000000  3210.129883  3184.169922  3185.270020  2093800
# 751 2020-12-24  3193.899902  3202.000000  3169.000000  3172.689941  1451900
# 752 2020-12-28  3194.000000  3304.000000  3172.689941  3283.959961  5686800
# 753 2020-12-29  3309.939941  3350.649902  3281.219971  3322.000000  4872900
# 754 2020-12-30  3341.000000  3342.100098  3282.469971  3285.850098  3209300
#
#     Ticker
# 750   AMZN
# 751   AMZN
# 752   AMZN
# 753   AMZN
# 754   AMZN

# %%
# missing rows had to reupload
goog_transformed.to_sql(name='Google_stocks', con=engine, if_exists='append', index=True)

# %%
result = stocks_appended.to_json(orient='records')
parsed = json.loads(result)
parsed
# Out:
# [{'Date': 1514851200000,
#   'Open': 1172.0,
#   'High': 1190.0,
#   'Low': 1170.51001,
#   'Adj_Close': 1189.01001,
#   'Volume': 2694500,
#   'Ticker': 'AMZN'},
#  {'Date': 1514937600000,
#   'Open': 1188.300049,
#   'High': 1205.48999,
#   'Low': 1188.300049,
#   'Adj_Close': 1204.199951,
#   'Volume': 3108800,
#   'Ticker': 'AMZN'},
#  {'Date': 1515024000000,
#   'Open': 1205.0,
#   'High': 1215.869995,
#   'Low': 1204.660034,
#   'Adj_Close': 1209.589966,
#   'Volume': 3022100,
#   'Ticker': 'AMZN'},
#  {'Date': 1515110400000,
#   'Open': 1217.51001,
#   'High': 1229.140015,
#   'Low': 1210.0,
#   'Adj_Close': 1229.140015,
#   'Volume': 3544700,
#   'Ticker': 'AMZN'},
#  {'Date': 1515369600000,
#   'Open': 1236.0,
#   'High': 1253.079956,
#   'Low': 1232.030029,
#   'Adj_Close': 1246.869995,
#   'Volume': 4279500,
#   'Ticker': 'AMZN'},
#  {'Date': 1515456000000,
#   'Open': 1256.900024,
#   'High': 1259.329956,
#   'Low': 1241.76001,
#   'Adj_Close': 1252.699951,
# ...

# %%
parsed.to_sql(name='json_stocks', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-48aedc88335d> in <module>
# ----> 1 parsed.to_sql(name='json_stocks', con=engine, if_exists='append', index=True)
#
# AttributeError: 'list' object has no attribute 'to_sql'

# %%
from sqlalchemy import inspect
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['fang_stocks_2018_2020',
#  'Amazon_stocks',
#  'Apple_stocks',
#  'Facebook_stocks',
#  'Micrsoft_stocks',
#  'Netflix_stocks',
#  'Google_stocks',
#  'Employee_numbers',
#  'office_locations',
#  'google_revenue',
#  'facebook_quarter',
#  'facebook_revenue']

# %%
Base = declarative_base()

# %%
Base.metadata.create_all(engine)
session = Session(bind=engine)

# %%
class stocks(Base):
    __tablename__ = "stockinfo"
    index = Column(Integer, primary_key= True)
    date =Column(Date)
    Open =Column(Float)
    High=Column(Float)
    Low=Column(Float)
    Adj_Close =Column(Float)
    Volume =Column(Integer)
    Ticker = Column(String)

# %%
dates = session.query(stocks)
for line in dates:
    print(line.date)
    break
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1245                     self.dialect.do_execute(
# -> 1246                         cursor, statement, parameters, context
#    1247                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     587     def do_execute(self, cursor, statement, parameters, context=None):
# --> 588         cursor.execute(statement, parameters)
#     589
#
# UndefinedTable: relation "stockinfo" does not exist
# LINE 2: FROM stockinfo
#              ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# ...
