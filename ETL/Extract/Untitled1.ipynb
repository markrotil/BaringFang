# %%
# Import Dependencies
import pandas as pd
import csv
from datetime import datetime as dt
from bs4 import BeautifulSoup as bs
import requests
import os
import numpy as np
from splinter import Browser
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
# claim URL and get response
url='https://jobs.netflix.com/search?location=Amsterdam%2C%20Netherlands~Tokyo%2C%20Japan~Sydney%2C%20Australia~Seoul%2C%20South%20Korea~Salt%20Lake%20City%2C%20Utah~Rome%2C%20Italy~Paris%2C%20France~Singapore%2C%20Singapore~New%20York%2C%20New%20York~Remote%2C%20United%20States~London%2C%20United%20Kingdom~Istanbul%2C%20Turkey~Hsinchu%20City%2C%20Taiwan~Berlin%2C%20Germany~Los%20Angeles%2C%20California~Los%20Gatos%2C%20California~Mumbai%2C%20India~Mexico%20City%2C%20Mexico~Manila%2C%20Philippines~Madrid%2C%20Spain~Alphaville%2C%20Brazil'
response = requests.get(url)

# %%
# Use beautiful soup to parse html
soup = bs(response.text, 'html.parser')

# %%
# inspect results from beautiful soup
results = soup.find_all("span", class_= "css-1vbg17 essqqm80")
results
# Out:
# [<span class="css-1vbg17 essqqm80" tabindex="-1"><style data-emotion-css="4lqhpq">.css-4lqhpq{padding-left:0.75rem;padding-right:0.75rem;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background:transparent;border:none;color:#221F1F;cursor:pointer;display:block;font-weight:500;font-size:1rem;outline:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;color:#221f1f;}@media (min-width:768px){.css-4lqhpq{padding-left:1.25rem;padding-right:1.25rem;}}@media (min-width:1440px){.css-4lqhpq{padding-left:1.25rem;padding-right:1.25rem;}}.css-4lqhpq svg{fill:#221F1F;width:1.19rem;height:1.13rem;}@media (min-width:1200px){.css-4lqhpq svg{margin-right:0.94rem;}}.css-4lqhpq svg{fill:#221f1f;}@media (min-width:945px){.css-4lqhpq{display:none;}}</style><span class="css-4lqhpq e10x19ms5"><svg><path d="M0 0h18v3H0V0zm0 6h18v3H0V6zm0 6h18v3H0v-3z" fill-rule="evenodd"></path></svg></span></span>,
# ...
