# %%
import csv
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect
from flask import Flask, jsonify
import pandas as pd
from datetime import datetime as dt
from bs4 import BeautifulSoup as bs
import requests
import os
import numpy as np
from splinter import Browser
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
url='https://www.macrotrends.net/stocks/charts/AAPL/apple/revenue'
response = requests.get(url)

# %%
soup = bs(response.text, 'html.parser')

# %%
results = soup.find_all("tbody")
results
# Out:
# [<tbody>
#  <tr>
#  <td style="text-align:center">2020</td>
#  <td style="text-align:center">$274,515</td>
#  </tr>
#  <tr>
#  <td style="text-align:center">2019</td>
#  <td style="text-align:center">$260,174</td>
#  </tr>
#  <tr>
#  <td style="text-align:center">2018</td>
#  <td style="text-align:center">$265,595</td>
#  </tr>
#  <tr>
#  <td style="text-align:center">2017</td>
#  <td style="text-align:center">$229,234</td>
#  </tr>
#  <tr>
#  <td style="text-align:center">2016</td>
#  <td style="text-align:center">$215,639</td>
#  </tr>
#  <tr>
#  <td style="text-align:center">2015</td>
#  <td style="text-align:center">$233,715</td>
#  </tr>
#  <tr>
#  <td style="text-align:center">2014</td>
#  <td style="text-align:center">$182,795</td>
#  </tr>
#  <tr>
#  <td style="text-align:center">2013</td>
#  <td style="text-align:center">$170,910</td>
#  </tr>
#  <tr>
#  <td style="text-align:center">2012</td>
#  <td style="text-align:center">$156,508</td>
#  </tr>
#  <tr>
# ...

# %%
revenue = []

results = soup.find_all("tr")
for result in results:
    money = result.find_all(style="text-align:center")
    print("-------------------")
    print(money)
    revenue.append(money)
    
    
money
# Out:
# -------------------
# [<th colspan="2" style="text-align:center">Apple Annual Revenue<br/><span style="font-size:14px;">(Millions of US $)</span></th>]
# -------------------
# [<td style="text-align:center">2020</td>, <td style="text-align:center">$274,515</td>]
# -------------------
# [<td style="text-align:center">2019</td>, <td style="text-align:center">$260,174</td>]
# -------------------
# [<td style="text-align:center">2018</td>, <td style="text-align:center">$265,595</td>]
# -------------------
# [<td style="text-align:center">2017</td>, <td style="text-align:center">$229,234</td>]
# -------------------
# [<td style="text-align:center">2016</td>, <td style="text-align:center">$215,639</td>]
# -------------------
# [<td style="text-align:center">2015</td>, <td style="text-align:center">$233,715</td>]
# -------------------
# [<td style="text-align:center">2014</td>, <td style="text-align:center">$182,795</td>]
# -------------------
# ...

# %%
df = pd.DataFrame = ({
    "Revenue" : revenue
})

# %%
df
df["Revenue"]= df["Revenue"].str.strip('style="text-align:center/ ?hl=en')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-82f0da66a680> in <module>
#       1 df
# ----> 2 df["Revenue"]= df["Revenue"].str.strip('style="text-align:center/ ?hl=en')
#
# AttributeError: 'list' object has no attribute 'str'

# %%
new_table = pd.DataFrame(columns=range(0,2), index = [0]) # I know the size 
    
for row in results.find_all('tr'):
    column_marker = 0
     columns = row.find_all('td')
    for column in columns:
        new_table.iat[row_marker,column_marker] = column.get_text()
        column_marker += 1
# Out:
#   File "<ipython-input-80-15d4f3a564ad>", line 5
#     columns = row.find_all('td')
#     ^
# IndentationError: unexpected indent

# %%
df = pd.read_json(revenue)
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-568bae708312> in <module>
# ----> 1 df = pd.read_json(revenue)
#       2 print(df)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     583     compression = infer_compression(path_or_buf, compression)
#     584     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# ...
