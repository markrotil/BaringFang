# %%
# Import Dependencies
import pandas as pd
import csv
import os
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect
from flask import Flask, jsonify

# %%
# Create CSv fielpaths
file1 = "apple.csv"
file2 = "amazon.csv"
file3 = "facebook.csv"
file4 = "google.csv"
file5 = "microsoft.csv"
file6 = "netflix.csv"

# %%
# reads the csv and transforms it into a dataframe
apple = pd.read_csv(file1, encoding='latin-1')
amazon = pd.read_csv(file2, encoding='latin-1')
facebook = pd.read_csv(file3, encoding='latin-1')
google = pd.read_csv(file4, encoding='latin-1')
microsoft = pd.read_csv(file5, encoding='latin-1')
netflix = pd.read_csv(file6, encoding='latin-1')

# %%
apple
# Out:
#                 Office                                            Address  \
# 0            Cupertino                                 One Apple Park Way
# 1               Austin                                   12801 Delcour Dr
# 2            Cupertino                                    1 Infinite Loop
# 3               Sydney                               Level 3/20 Martin Pl
# 4              Toronto                              1600 120 Bremner Blvd
# 5           Las Condes                                Cerro El Plomo 5630
# 6             Shanghai                  Building 6, Block C, 88 Maji Road
# 7                Paris                                     7 Place d'Iéna
# 8            Hong Kong                        1 Matheson St, Causeway Bay
# 9            Bengaluru                     UB City No.24 Vittal Mallya Rd
# 10             Jakarta  World Trade Center II, Jl. Jend. Sudirman, RT....
# 11                Cork                                       Hollyhill Ln
# 12               Tokyo                   6 Chome-11-1 Roppongi, Minato-ku
# 13           South Bay     Edificio Luen Pong 743-763 Av. da Praia Grande
# 14        Kuala Lumpur  Level 11 Menara CIMB, Jalan Stesen Sentral 2, ...
# 15    Ciudad de México  Prolongacion Paseo de la Reforma 600, Santa Fe...
# 16            Auckland                                88 Shortland Street
# 17              Moskva                     Romanov Pereulok, 2 ???????? 1
# 18           Singapore                             7 Ang Mo Kio Street 64
# 19               Seoul  3901, ASEM Tower; 517 Yeongdong-daero, Gangnam-Gu
# 20         Taipei City                        Songren Rd., Xinyi District
# 21  Khwaeng Pathum Wan                                    999/9 Rama I Rd
# 22            ?stanbul  Levaz?m, Zorlu Center, 34340 Be?ikta?/?stanbul...
# 23               Dubai      Office 302, Level 3, Building 4, Emaar Square
# 24         Ho Chi Minh  Unit 901, Deutsches Haus Ho Chi Minh City. No....
#
#    State               Country Company   Latitude   Longitude
# 0     CA         United States   Apple  37.335560 -122.014616
# 1     TX         United States   Apple  30.434736  -97.734340
# 2     CA         United States   Apple  37.332041 -122.029597
# 3    NaN             Australia   Apple -33.867097  151.208785
# 4    NaN                Canada   Apple  43.643140  -79.383077
# 5    NaN                 Chile   Apple -33.405164  -70.574288
# 6    NaN                 China   Apple  31.349153  121.590206
# 7    NaN                France   Apple  48.864135    2.293747
# 8    NaN             Hong Kong   Apple  22.278409  114.182017
# 9    NaN                 India   Apple  12.971903   77.596048
# 10   NaN             Indonesia   Apple  -6.215286  106.821454
# 11   NaN               Ireland   Apple  51.902594   -8.503932
# 12   NaN                 Japan   Apple  35.658893  139.731935
# 13   NaN                 Macao   Apple  22.193096  113.542660
# 14   NaN              Malaysia   Apple   3.136566  101.686536
# 15   NaN                Mexico   Apple  19.376209  -99.257876
# 16   NaN           New Zealand   Apple -36.846280  174.769816
# 17   NaN                Russia   Apple  55.754241   37.608498
# 18   NaN             Singapore   Apple   1.389529  103.845005
# 19   NaN   Korea (Republic of)   Apple  37.511906  127.059329
# 20   NaN                Taiwan   Apple  25.034001  121.564530
# 21   NaN              Thailand   Apple  13.746235  100.538463
# 22   NaN                Turkey   Apple  41.066411   29.017211
# 23   NaN  United Arab Emirates   Apple  25.200908   55.273999
# 24   NaN              Viet Nam   Apple  10.781916  106.700779

# %%
amazon
# Out:
#                  Office                                Address       State  \
# 0               Seattle                        410 Terry Ave N  Washington
# 1             Arlington                           Crystal City     Virgina
# 2               Atlanta                    3333 Piedmont Rd NE     Georgia
# 3                Austin                     11501 Alterra Pkwy       Texas
# 4             Baltimore                      2010 Broening Hwy    Maryland
# ..                  ...                                    ...         ...
# 227             Rugeley  tower business park, Power Station Rd         NaN
# 228        Severn Beach     Western Approach Distribution Park         NaN
# 229              Skewen                 Ffordd Amazon,Swansea          NaN
# 230  Sutton-in-Ashfield              Sherwood Way S, Mansfield         NaN
# 231             Tilbury  London Distribution Park, Windrush Rd         NaN
#
#             Country Company   Latitude   Longitude
# 0     United States  Amazon  47.624659 -122.336501
# 1     United States  Amazon  38.858320  -77.051753
# 2     United States  Amazon  33.848270  -84.372043
# 3     United States  Amazon  30.406992  -97.719013
# 4     United States  Amazon  39.268290  -76.549762
# ..              ...     ...        ...         ...
# 227  United Kingdom  Amazon  52.757788   -1.926376
# 228  United Kingdom  Amazon  51.542131   -2.641466
# 229  United Kingdom  Amazon  51.624661   -3.864105
# 230  United Kingdom  Amazon  53.126589   -1.218308
# 231  United Kingdom  Amazon  51.468027    0.353233
#
# [232 rows x 7 columns]

# %%
google
# Out:
#            Office                                      Address State  \
# 0   Mountain View                       1600 Amphitheatre Pkwy    CA
# 1       Ann Arbor                           2300 Traverwood Dr    MI
# 2         Atlanta                                10 10th St NE    GA
# 3          Austin                           500 W 2nd St #2900    TX
# 4         Boulder                                2600 Pearl St    CO
# ..            ...                                          ...   ...
# 79       Istanbul               Eski Buyukdere Caddesi No: 209   NaN
# 80          Dubai              TECOM Zone, Dubai Internet City   NaN
# 81         London                        1-13 St Giles High St   NaN
# 82         London                             6 Pancras Square   NaN
# 83         London  Belgrave House\r\n76 Buckingham Palace Road   NaN
#
#                  Country Company   Latitude   Longitude
# 0          United States  Google  37.421512 -122.084101
# 1          United States  Google  42.306385  -83.714083
# 2          United States  Google  33.781827  -84.387301
# 3          United States  Google  30.266035  -97.749237
# 4          United States  Google  40.021693 -105.260139
# ..                   ...     ...        ...         ...
# 79                Turkey  Google  41.081697   29.008590
# 80  United Arab Emirates  Google  25.092900   55.159100
# 81        United Kingdom  Google  51.516027   -0.127550
# 82        United Kingdom  Google  51.533311   -0.126026
# 83        United Kingdom  Google  51.494961   -0.146652
#
# [84 rows x 7 columns]

# %%
microsoft
# Out:
#          Office                                            Address State  \
# 0       Redmond         Microsoft Corporation\r\nOne Microsoft Way    WA
# 1        Albany                    54 State St 7th Floor Suite 701    NY
# 2    Alpharetta                              8000 Avalon Blvd #800    GA
# 3       Atlanta                                    84 Peachtree St    GA
# 4        Austin                          10900 Stonelake Blvd #225    TX
# ..          ...                                                ...   ...
# 172     Belfast      11 Queens Rd, Belfast BT3 9AD, United Kingdom   NaN
# 173   Wokingham              Thames Valley Park Reading Berkshire    NaN
# 174  Montevideo   Mercosur Business Center Cebollati 1474 - Piso 5   NaN
# 175     Caracas  Av. Principal de La Castellana Centro Letonia ...   NaN
# 176       Hanoi  16th Floor, Capital Tower Building, 109 Tran H...   NaN
#
#             Country    Company   Latitude   Longitude
# 0     United States  Microsoft  47.653056 -122.142295
# 1     United States  Microsoft  42.648902  -73.752147
# 2     United States  Microsoft  34.070612  -84.274290
# 3     United States  Microsoft  33.756055  -84.388769
# 4     United States  Microsoft  30.401495  -97.735258
# ..              ...        ...        ...         ...
# 172  United Kingdom  Microsoft  54.612823   -5.902655
# 173  United Kingdom  Microsoft  51.461290   -0.927148
# 174         Uruguay  Microsoft -34.913532  -56.182471
# 175       Venezuela  Microsoft  10.497164  -66.851356
# 176        Viet Nam  Microsoft  21.023761  105.841917
#
# [177 rows x 7 columns]

# %%
netflix
# Out:
#          Office                                            Address State  \
# 0     Los Gatos                                 100 Winchester Cir    CA
# 1   Los Angeles                                   5808 Sunset Blvd    CA
# 2      New York                245 W 17th St, New York, NY 10011,     NY
# 3          Utah        401 Jimmy Doolittle Rd #120, Salt Lake City   UT
# 4    Washington  1455 Pennsylvania Avenue NW, Washington, DC 20...    DC
# 5         Paris                            148 Rue de l'Université   NaN
# 6        Berlin          Friedrichstraße 88, 10117 Berlin, Germany   NaN
# 7   Mexico City                                                NaN   NaN
# 8     Amsterdam                                     Karperstraat 8   NaN
# 9     Amsterdam                     9V5Q+G8 Amsterdam, Netherlands   NaN
# 10       Manila  New Era, Quezon City, 2516 Metro Manila, Phili...   NaN
# 11    Singapore  9 Straits View, #23-07/12 Marina One West Towe...   NaN
# 12       Madrid                                                NaN   NaN
# 13      Hsinchu    Room 15-7,Guansin Road Lane 27, Hsinchu, Taiwan   NaN
# 14       London       8 Mortimer St, Fitzrovia, London W1T 3NA, UK   NaN
# 15    Argentina                950 A, Av. Córdoba, CABA, Argentina   NaN
# 16       Brasil  Alameda Xingu, 350 - Alphaville Industrial, Ba...   NaN
# 17        India  G Block BKC, Bandra Kurla Complex, Bandra East...   NaN
# 18        Seoul  63 Gongpyeong-dong, Jongno-gu, Seoul, South Korea   NaN
# 19        Tokyo  Japan, ?107-0062 Tokyo, Minato City, Minamiaoy...   NaN
# 20       Turkey  Ç?nar, Metro, 5003 sok, Gümü? Plaza no 2 2 D: ...   NaN
# 21         Rome          Via Boncompagni, 10, 00187 Roma RM, Italy   NaN
#
#                       Country  Company   Latitude   Longitude
# 0               United States  Netflix  37.259695 -121.962699
# 1               United States  Netflix  34.097876 -118.316354
# 2               United States  Netflix  40.742949  -73.999769
# 3               United States  Netflix  40.778032 -112.020770
# 4               United States  Netflix  38.897974  -77.033059
# 5                      France  Netflix  48.861318    2.309316
# 6                     Germany  Netflix  52.517730   13.389605
# 7                      Mexico  Netflix  19.441192  -99.152548
# 8                 Netherlands  Netflix  52.348046    4.856101
# 9                 Netherlands  Netflix  52.358919    4.888270
# 10                Philippines  Netflix  14.664354  121.051483
# 11                  Singapore  Netflix   1.276879  103.852401
# 12                      Spain  Netflix  40.433339   -3.728104
# 13  Taiwan, Province of China  Netflix  24.784853  121.018046
# 14             United Kingdom  Netflix  51.518848   -0.138043
# 15                  Argentina  Netflix -34.598874  -58.380513
# 16                     Brazil  Netflix -23.504744  -46.849367
# 17                      India  Netflix  19.992861   72.716200
# 18                      Korea  Netflix  37.571539  126.983230
# 19                      Japan  Netflix  35.666616  139.713941
# 20                     Turkey  Netflix  38.441295   27.181219
# 21                      Italy  Netflix  41.908341   12.493059

# %%
# Combine all dataframes to one dataframe
company_office = apple.append([amazon, facebook, google, microsoft, netflix])
company_office
# Out:
#        Office                                            Address State  \
# 0   Cupertino                                 One Apple Park Way    CA
# 1      Austin                                   12801 Delcour Dr    TX
# 2   Cupertino                                    1 Infinite Loop    CA
# 3      Sydney                               Level 3/20 Martin Pl   NaN
# 4     Toronto                              1600 120 Bremner Blvd   NaN
# ..        ...                                                ...   ...
# 17      India  G Block BKC, Bandra Kurla Complex, Bandra East...   NaN
# 18      Seoul  63 Gongpyeong-dong, Jongno-gu, Seoul, South Korea   NaN
# 19      Tokyo  Japan, ?107-0062 Tokyo, Minato City, Minamiaoy...   NaN
# 20     Turkey  Ç?nar, Metro, 5003 sok, Gümü? Plaza no 2 2 D: ...   NaN
# 21       Rome          Via Boncompagni, 10, 00187 Roma RM, Italy   NaN
#
#           Country  Company   Latitude   Longitude
# 0   United States    Apple  37.335560 -122.014616
# 1   United States    Apple  30.434736  -97.734340
# 2   United States    Apple  37.332041 -122.029597
# 3       Australia    Apple -33.867097  151.208785
# 4          Canada    Apple  43.643140  -79.383077
# ..            ...      ...        ...         ...
# 17          India  Netflix  19.992861   72.716200
# 18          Korea  Netflix  37.571539  126.983230
# 19          Japan  Netflix  35.666616  139.713941
# 20         Turkey  Netflix  38.441295   27.181219
# 21          Italy  Netflix  41.908341   12.493059
#
# [625 rows x 7 columns]

# %%
# Drop the columns that aren't needed
company_office = company_office.drop(['Address', 'State'], axis=1)

# %%
company_office.set_index('Company')
# Out:
#             Office        Country   Latitude   Longitude
# Company
# Apple    Cupertino  United States  37.335560 -122.014616
# Apple       Austin  United States  30.434736  -97.734340
# Apple    Cupertino  United States  37.332041 -122.029597
# Apple       Sydney      Australia -33.867097  151.208785
# Apple      Toronto         Canada  43.643140  -79.383077
# ...            ...            ...        ...         ...
# Netflix      India          India  19.992861   72.716200
# Netflix      Seoul          Korea  37.571539  126.983230
# Netflix      Tokyo          Japan  35.666616  139.713941
# Netflix     Turkey         Turkey  38.441295   27.181219
# Netflix       Rome          Italy  41.908341   12.493059
#
# [625 rows x 4 columns]

# %%
# Create engien that connects to ElephantSQl
engine = create_engine("postgres://qzewnmvp:KLrEMMwqNGoGYgkvTiI5pNANap7CuFbP@ziggy.db.elephantsql.com:5432/qzewnmvp")
Base = automap_base()
Base.prepare(engine, reflect= True)

# %%
# Create a session
session = Session(engine)

# %%
# Append to SQl cloud AWS
company_office.to_sql(name='office_locations', con=engine, if_exists='append', index=True)

# %%
# Pull the from the SQl website to verify it is there
offices = pd.read_sql("SELECT * FROM office_locations", con=engine)
offices
# Out:
#      index     Office        Country  Company   Latitude   Longitude
# 0        0  Cupertino  United States    Apple  37.335560 -122.014616
# 1        1     Austin  United States    Apple  30.434736  -97.734340
# 2        2  Cupertino  United States    Apple  37.332041 -122.029597
# 3        3     Sydney      Australia    Apple -33.867097  151.208785
# 4        4    Toronto         Canada    Apple  43.643140  -79.383077
# ..     ...        ...            ...      ...        ...         ...
# 620     17      India          India  Netflix  19.992861   72.716200
# 621     18      Seoul          Korea  Netflix  37.571539  126.983230
# 622     19      Tokyo          Japan  Netflix  35.666616  139.713941
# 623     20     Turkey         Turkey  Netflix  38.441295   27.181219
# 624     21       Rome          Italy  Netflix  41.908341   12.493059
#
# [625 rows x 6 columns]
