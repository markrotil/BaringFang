# %%
import pandas as pd
from fbprophet import Prophet

# %%
df = pd.read_csv('micrsoft_quarter.csv')
df.tail()
# Out:
#    Quarter_Date  Microsoft_Revenue(Millions$US)
# 59   2006-03-31                           10900
# 60   2005-12-31                           11837
# 61   2005-09-30                            9741
# 62   2005-06-30                           10161
# 63   2005-03-31                            9620

# %%
company_quarter= df.rename(columns={"Quarter_Date": 'ds', 
                                 "Microsoft_Revenue(Millions$US)": 'y'})
company_quarter
# Out:
#             ds      y
# 0   2020-12-31  43076
# 1   2020-09-30  37154
# 2   2020-06-30  38033
# 3   2020-03-31  35021
# 4   2019-12-31  36906
# ..         ...    ...
# 59  2006-03-31  10900
# 60  2005-12-31  11837
# 61  2005-09-30   9741
# 62  2005-06-30  10161
# 63  2005-03-31   9620
#
# [64 rows x 2 columns]

# %%
model = Prophet()
model.fit(company_quarter)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = model.make_future_dataframe(periods=8, freq='Q')
future.tail()
# Out:
#            ds
# 67 2021-12-31
# 68 2022-03-31
# 69 2022-06-30
# 70 2022-09-30
# 71 2022-12-31

# %%
forecast = model.predict(future)

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(20)
# Out:
#            ds          yhat    yhat_lower    yhat_upper
# 52 2018-03-31  27631.080902  26131.114587  29107.218760
# 53 2018-06-30  29297.111623  27711.180161  30846.812024
# 54 2018-09-30  29265.274309  27646.368849  30776.583343
# 55 2018-12-31  33327.898623  31850.138179  34742.993050
# 56 2019-03-31  31602.136175  30042.864291  33007.933125
# 57 2019-06-30  33212.351336  31751.554764  34776.008375
# 58 2019-09-30  33242.455032  31838.691079  34738.081244
# 59 2019-12-31  36900.938388  35330.127196  38217.445056
# 60 2020-03-31  34748.222030  33210.648613  36179.763596
# 61 2020-06-30  37519.196287  35947.867843  38966.319208
# 62 2020-09-30  36088.004453  34548.262546  37599.972038
# 63 2020-12-31  41003.794480  39606.372768  42530.910741
# 64 2021-03-31  38547.612096  37077.301153  39955.259305
# 65 2021-06-30  40601.868272  39151.394478  42067.427693
# 66 2021-09-30  40083.265209  38661.311588  41570.507842
# 67 2021-12-31  44564.404196  43135.060508  46075.412715
# 68 2022-03-31  42434.371860  40914.435249  43932.189512
# 69 2022-06-30  44100.402581  42557.313688  45563.798023
# 70 2022-09-30  44068.565267  42530.391760  45608.873162
# 71 2022-12-31  48131.189581  46705.759476  49647.798227

# %%
plot2 = model.plot_components(forecast)

# %%
plot1 = model.plot(forecast)
