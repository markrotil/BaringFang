# %%
import pandas as pd
from fbprophet import Prophet

# %%
df = pd.read_csv('amazon_quarter.csv')
df.tail()
# Out:
#    Quarter_Date  Amazon_Revenue(Millions$US)
# 59   2006-03-31                         2279
# 60   2005-12-31                         2977
# 61   2005-09-30                         1858
# 62   2005-06-30                         1753
# 63   2005-03-31                         1902

# %%
company_quarter= df.rename(columns={"Quarter_Date": 'ds', 
                                 "Amazon_Revenue(Millions$US)": 'y'})
company_quarter
# Out:
#             ds       y
# 0   2020-12-31  125555
# 1   2020-09-30   96145
# 2   2020-06-30   88912
# 3   2020-03-31   75452
# 4   2019-12-31   87437
# ..         ...     ...
# 59  2006-03-31    2279
# 60  2005-12-31    2977
# 61  2005-09-30    1858
# 62  2005-06-30    1753
# 63  2005-03-31    1902
#
# [64 rows x 2 columns]

# %%
model = Prophet()
model.fit(company_quarter)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = model.make_future_dataframe(periods=8, freq='Q')
future.tail()
# Out:
#            ds
# 67 2021-12-31
# 68 2022-03-31
# 69 2022-06-30
# 70 2022-09-30
# 71 2022-12-31

# %%
forecast = model.predict(future)

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(20)
# Out:
#            ds           yhat     yhat_lower     yhat_upper
# 52 2018-03-31   51975.296964   47474.170942   56410.049968
# 53 2018-06-30   54518.492550   50179.266092   59017.106563
# 54 2018-09-30   59172.651044   54935.687175   63903.212939
# 55 2018-12-31   69322.689335   65301.924140   73889.348667
# 56 2019-03-31   66062.146788   61344.870823   70454.167026
# 57 2019-06-30   69409.485822   64705.325601   73907.424733
# 58 2019-09-30   73858.660130   69494.190008   78540.220437
# 59 2019-12-31   85300.266954   80947.424936   89827.117729
# 60 2020-03-31   82631.402513   78293.947129   86723.102199
# 61 2020-06-30   88347.969217   83902.238138   93067.138404
# 62 2020-09-30   93108.520461   88831.585165   97676.784320
# 63 2020-12-31  107333.616768  102508.087616  111642.686350
# 64 2021-03-31  100080.587680   95794.132361  104779.147347
# 65 2021-06-30  103403.838587   98702.228579  107677.342113
# 66 2021-09-30  108162.212124  103641.302738  112493.509711
# 67 2021-12-31  119248.148090  114602.081376  123798.124907
# 68 2022-03-31  115840.275900  111127.225681  120860.913657
# 69 2022-06-30  118383.471485  113699.267449  122676.679876
# 70 2022-09-30  123037.629980  118315.131021  127887.038505
# 71 2022-12-31  133187.668271  128146.748775  138260.143632

# %%
plot2 = model.plot_components(forecast)

# %%
plot1 = model.plot(forecast)
